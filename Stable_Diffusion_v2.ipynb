# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamayB/Text_to_image_Stable_Diffusion_v2/blob/main/Stable_Diffusion_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
# !pip install git+https://github.com/huggingface/diffusers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-ipjcrs68
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-ipjcrs68
#   Resolved https://github.com/huggingface/diffusers to commit c42f6ee43e0408c5fe8a1d3dc3cdeb9eb3a02fa6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 110.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.5 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

model_id = "stabilityai/stable-diffusion-2"


scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# ...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# ...
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .

# %%
import matplotlib.pyplot as plt

# %%
def imgGen(prompt):
  image = pipe(prompt).images[0]
  plt.imshow(image)
  plt.axis("off")
  plt.show()

# %%
prompt=input("Enter text prompt here.")
for i in range(0,3):
  imgGen(prompt)
# Out:
# Enter text prompt here.steampunk starship flying through space realistic, trending on art station
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
